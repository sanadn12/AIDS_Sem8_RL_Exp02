# %% [markdown]
# # Sanad Naqvi || 221A023 ||29

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('/content/Ads_Optimisation (1).csv')
# Out:
# Sanad Naqvi || 221A023

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
import random
N = 10000
d = 10
ads_selected_random = []
total_reward_random = 0
for n in range(0, N):
    ad = random.randrange(d)  # random add selection
    ads_selected_random.append(ad)
    reward = dataset.values[n, ad]
    total_reward_random = total_reward_random + reward
# Out:
# Sanad Naqvi || 221A023

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
print(total_reward_random)
# Out:
# Sanad Naqvi || 221A023
# 1206

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
import math
import pandas as pd

# Implementing UCB
N = 10000
d = 10
ads_selected = []
numbers_of_selections = [0] * d
sums_of_reward = [0] * d
total_reward = 0

for n in range(0, N):
    ad = 0
    max_upper_bound = 0
    for i in range(0, d):
        if (numbers_of_selections[i] > 0):
            average_reward = sums_of_reward[i] / numbers_of_selections[i]
            # Calculating the confidence interval (delta)
            delta_i = math.sqrt(3/2 * math.log(n + 1) / numbers_of_selections[i])
            upper_bound = average_reward + delta_i
        else:
            # High value to ensure every ad is selected at least once at the start
            upper_bound = 1e400

        if upper_bound > max_upper_bound:
            max_upper_bound = upper_bound
            ad = i

    # --- Updating variables ---
    ads_selected.append(ad)
    numbers_of_selections[ad] += 1
    reward = dataset.values[n, ad]
    sums_of_reward[ad] += reward
    total_reward += reward
# Out:
# Sanad Naqvi || 221A023

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
print(f"Total Reward (UCB): {total_reward}")
# Out:
# Sanad Naqvi || 221A023
# Total Reward (UCB): 2178

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
print(f"Total Reward (Random Selection): {total_reward_random}")
print(f"Total Reward (UCB): {total_reward}")
# Out:
# Sanad Naqvi || 221A023
# Total Reward (Random Selection): 1206
# Total Reward (UCB): 2178

# %%
print("Sanad Naqvi || 221A023")
# Sanad Naqvi || 221A023 ||29
pd.Series(ads_selected_random).tail(1000).value_counts()
# Out:
# Sanad Naqvi || 221A023
# 5    120
# 3    107
# 9    107
# 6    107
# 7     99
# 8     98
# 2     98
# 0     94
# 1     93
# 4     77
# Name: count, dtype: int64

# %% [markdown]
# ## **Conclusion:**

# %% [markdown]
# .

# %% [markdown]
# ## **CO's Covered :**
